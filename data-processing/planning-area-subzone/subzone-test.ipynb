# %%
import json

file = None
with open('formatted-data.json') as f:
    file = json.load(f)

file
# Out:
# [{'subzone': 'DEPOT ROAD',
#   'planning_area': 'BUKIT MERAH',
#   'region': 'CENTRAL REGION',
#   'coordinates': [[1.28238675809122, 103.814542206408],
#    [1.28043473155531, 103.817736334915],
#    [1.28003747873544, 103.817494849843],
#    [1.28079786193675, 103.816434785704],
#    [1.28088115685082, 103.816193126886],
#    [1.28094112783159, 103.81590181139],
#    [1.28094276580602, 103.815405200951],
#    [1.28112587091266, 103.813709348731],
#    [1.28109770353196, 103.813705195003],
#    [1.28099119366765, 103.813692388947],
#    [1.28099258809907, 103.813679527259],
#    [1.28099454410096, 103.813661481001],
#    [1.28023136533654, 103.81358262663],
#    [1.28017940718972, 103.813625142252],
#    [1.28010605424736, 103.813637289248],
#    [1.28023135727246, 103.812568370389],
#    [1.28021316505293, 103.812566467432],
#    [1.28023963490983, 103.812345859062],
#    [1.2803284899742, 103.811627344186],
#    [1.28035298174758, 103.811388634766],
# ...

# %%
len(file)
# Out:
# 332
